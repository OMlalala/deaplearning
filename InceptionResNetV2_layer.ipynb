# %%
from keras.layers import Input, merge, Dropout, Dense, Lambda, Flatten, Activation
from keras.layers.convolutional import MaxPooling2D, Convolution2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model

from keras import backend as K

import warnings
warnings.filterwarnings('ignore')

"""
Implementation of Inception-Residual Network v1 [Inception Network v4 Paper](http://arxiv.org/pdf/1602.07261v1.pdf) in Keras.

Some additional details:
[1] Each of the A, B and C blocks have a 'scale_residual' parameter.
    The scale residual parameter is according to the paper. It is however turned OFF by default.

    Simply setting 'scale=True' in the create_inception_resnet_v2() method will add scaling.

[2] There were minor inconsistencies with filter size in both B and C blocks.

    In the B blocks: 'ir_conv' nb of filters  is given as 1154, however input size is 1152.
    This causes inconsistencies in the merge-add mode, therefore the 'ir_conv' filter size
    is reduced to 1152 to match input size.

    In the C blocks: 'ir_conv' nb of filter is given as 2048, however input size is 2144.
    This causes inconsistencies in the merge-add mode, therefore the 'ir_conv' filter size
    is increased to 2144 to match input size.

    Currently trying to find a proper solution with original nb of filters.

[3] In the stem function, the last Convolutional2D layer has 384 filters instead of the original 256.
    This is to correctly match the nb of filters in 'ir_conv' of the next A blocks.
"""

def inception_resnet_stem(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input Shape is 299 x 299 x 3 (th) or 3 x 299 x 299 (th)
    c = Convolution2D(32, 3, 3, activation='relu', subsample=(2, 2))(input)
    c = Convolution2D(32, 3, 3, activation='relu', )(c)
    c = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(c)

    c1 = MaxPooling2D((3, 3), strides=(2, 2))(c)
    c2 = Convolution2D(96, 3, 3, activation='relu', subsample=(2, 2))(c)

    m = merge([c1, c2], mode='concat', concat_axis=channel_axis)

    c1 = Convolution2D(64, 1, 1, activation='relu', border_mode='same')(m)
    c1 = Convolution2D(96, 3, 3, activation='relu', )(c1)

    c2 = Convolution2D(64, 1, 1, activation='relu', border_mode='same')(m)
    c2 = Convolution2D(64, 7, 1, activation='relu', border_mode='same')(c2)
    c2 = Convolution2D(64, 1, 7, activation='relu', border_mode='same')(c2)
    c2 = Convolution2D(96, 3, 3, activation='relu', border_mode='valid')(c2)

    m2 = merge([c1, c2], mode='concat', concat_axis=channel_axis)

    p1 = MaxPooling2D((3, 3), strides=(2, 2), )(m2)
    p2 = Convolution2D(192, 3, 3, activation='relu', subsample=(2, 2))(m2)

    m3 = merge([p1, p2], mode='concat', concat_axis=channel_axis)
    m3 = BatchNormalization(axis=channel_axis)(m3)
    m3 = Activation('relu')(m3)
    return m3

def inception_resnet_v2_A(input, scale_residual=True):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input is relu activation
    init = input

    ir1 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(ir2)

    ir3 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)
    ir3 = Convolution2D(48, 3, 3, activation='relu', border_mode='same')(ir3)
    ir3 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(ir3)

    ir_merge = merge([ir1, ir2, ir3], concat_axis=channel_axis, mode='concat')

    ir_conv = Convolution2D(384, 1, 1, activation='linear', border_mode='same')(ir_merge)
    if scale_residual: ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=channel_axis)(out)
    out = Activation("relu")(out)
    return out

def inception_resnet_v2_B(input, scale_residual=True):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input is relu activation
    init = input

    ir1 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(128, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(160, 1, 7, activation='relu', border_mode='same')(ir2)
    ir2 = Convolution2D(192, 7, 1, activation='relu', border_mode='same')(ir2)

    ir_merge = merge([ir1, ir2], mode='concat', concat_axis=channel_axis)

    ir_conv = Convolution2D(1152, 1, 1, activation='linear', border_mode='same')(ir_merge)
    if scale_residual: ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=channel_axis)(out)
    out = Activation("relu")(out)
    return out

def inception_resnet_v2_C(input, scale_residual=True):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input is relu activation
    init = input

    ir1 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(224, 1, 3, activation='relu', border_mode='same')(ir2)
    ir2 = Convolution2D(256, 3, 1, activation='relu', border_mode='same')(ir2)

    ir_merge = merge([ir1, ir2], mode='concat', concat_axis=channel_axis)

    ir_conv = Convolution2D(2144, 1, 1, activation='linear', border_mode='same')(ir_merge)
    if scale_residual: ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=channel_axis)(out)
    out = Activation("relu")(out)
    return out


def reduction_A(input, k=192, l=224, m=256, n=384):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = MaxPooling2D((3,3), strides=(2,2))(input)

    r2 = Convolution2D(n, 3, 3, activation='relu', subsample=(2,2))(input)

    r3 = Convolution2D(k, 1, 1, activation='relu', border_mode='same')(input)
    r3 = Convolution2D(l, 3, 3, activation='relu', border_mode='same')(r3)
    r3 = Convolution2D(m, 3, 3, activation='relu', subsample=(2,2))(r3)

    m = merge([r1, r2, r3], mode='concat', concat_axis=channel_axis)
    m = BatchNormalization(axis=1)(m)
    m = Activation('relu')(m)
    return m


def reduction_resnet_v2_B(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = MaxPooling2D((3,3), strides=(2,2), border_mode='valid')(input)

    r2 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r2 = Convolution2D(384, 3, 3, activation='relu', subsample=(2,2))(r2)

    r3 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r3 = Convolution2D(288, 3, 3, activation='relu', subsample=(2, 2))(r3)

    r4 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r4 = Convolution2D(288, 3, 3, activation='relu', border_mode='same')(r4)
    r4 = Convolution2D(320, 3, 3, activation='relu', subsample=(2, 2))(r4)

    m = merge([r1, r2, r3, r4], concat_axis=channel_axis, mode='concat')
    m = BatchNormalization(axis=channel_axis)(m)
    m = Activation('relu')(m)
    return m

def create_inception_resnet_v2(nb_classes=1001, scale=True):
    '''
    Creates a inception resnet v2 network

    :param nb_classes: number of classes.txt
    :param scale: flag to add scaling of activations
    :return: Keras Model with 1 input (299x299x3) input shape and 2 outputs (final_output, auxiliary_output)
    '''

    if K.image_dim_ordering() == 'th':
        init = Input((3, 299, 299))
    else:
        init = Input((299, 299, 3))

    # Input Shape is 299 x 299 x 3 (tf) or 3 x 299 x 299 (th)
    x = inception_resnet_stem(init)

    # 10 x Inception Resnet A
    for i in range(10):
        x = inception_resnet_v2_A(x, scale_residual=scale)

    # Reduction A
    x = reduction_A(x, k=256, l=256, m=384, n=384)

    # 20 x Inception Resnet B
    for i in range(20):
        x = inception_resnet_v2_B(x, scale_residual=scale)

    # Auxiliary tower
    aux_out = AveragePooling2D((5, 5), strides=(3, 3))(x)
    aux_out = Convolution2D(128, 1, 1, border_mode='same', activation='relu')(aux_out)
    aux_out = Convolution2D(768, 5, 5, activation='relu')(aux_out)
    aux_out = Flatten()(aux_out)
    aux_out = Dense(nb_classes, activation='softmax')(aux_out)

    # Reduction Resnet B
    x = reduction_resnet_v2_B(x)

    # 10 x Inception Resnet C
    for i in range(10):
        x = inception_resnet_v2_C(x, scale_residual=scale)

    # Average Pooling
    x = AveragePooling2D((8,8))(x)

    # Dropout
    x = Dropout(0.8)(x)
    x = Flatten()(x)

    # Output
    out = Dense(output_dim=nb_classes, activation='softmax')(x)

    model = Model(init, output=[out, aux_out], name='Inception-Resnet-v2')
    return model

if __name__ == "__main__":
    #from keras.utils.visualize_util import plot

    inception_resnet_v2 = create_inception_resnet_v2()
    #inception_resnet_v2.summary()

    #plot(inception_resnet_v2, to_file="Inception ResNet-v2.png", show_shapes=True)
    res2=create_inception_resnet_v2()
    print(res2.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_977 (Conv2D)             (None, 149, 149, 32) 896         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_978 (Conv2D)             (None, 147, 147, 32) 9248        conv2d_977[0][0]
# __________________________________________________________________________________________________
# conv2d_979 (Conv2D)             (None, 147, 147, 64) 18496       conv2d_978[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 73, 73, 64)   0           conv2d_979[0][0]
# __________________________________________________________________________________________________
# conv2d_980 (Conv2D)             (None, 73, 73, 96)   55392       conv2d_979[0][0]
# __________________________________________________________________________________________________
# merge_341 (Merge)               (None, 73, 73, 160)  0           max_pooling2d_17[0][0]
#                                                                  conv2d_980[0][0]
# __________________________________________________________________________________________________
# conv2d_983 (Conv2D)             (None, 73, 73, 64)   10304       merge_341[0][0]
# __________________________________________________________________________________________________
# conv2d_984 (Conv2D)             (None, 73, 73, 64)   28736       conv2d_983[0][0]
# __________________________________________________________________________________________________
# conv2d_981 (Conv2D)             (None, 73, 73, 64)   10304       merge_341[0][0]
# __________________________________________________________________________________________________
# conv2d_985 (Conv2D)             (None, 73, 73, 64)   28736       conv2d_984[0][0]
# __________________________________________________________________________________________________
# conv2d_982 (Conv2D)             (None, 71, 71, 96)   55392       conv2d_981[0][0]
# __________________________________________________________________________________________________
# conv2d_986 (Conv2D)             (None, 71, 71, 96)   55392       conv2d_985[0][0]
# __________________________________________________________________________________________________
# merge_342 (Merge)               (None, 71, 71, 192)  0           conv2d_982[0][0]
#                                                                  conv2d_986[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 35, 35, 192)  0           merge_342[0][0]
# __________________________________________________________________________________________________
# conv2d_987 (Conv2D)             (None, 35, 35, 192)  331968      merge_342[0][0]
# __________________________________________________________________________________________________
# merge_343 (Merge)               (None, 35, 35, 384)  0           max_pooling2d_18[0][0]
#                                                                  conv2d_987[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 35, 35, 384)  1536        merge_343[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 35, 35, 384)  0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_991 (Conv2D)             (None, 35, 35, 32)   12320       activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d_989 (Conv2D)             (None, 35, 35, 32)   12320       activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d_992 (Conv2D)             (None, 35, 35, 48)   13872       conv2d_991[0][0]
# __________________________________________________________________________________________________
# conv2d_988 (Conv2D)             (None, 35, 35, 32)   12320       activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d_990 (Conv2D)             (None, 35, 35, 32)   9248        conv2d_989[0][0]
# __________________________________________________________________________________________________
# conv2d_993 (Conv2D)             (None, 35, 35, 64)   27712       conv2d_992[0][0]
# __________________________________________________________________________________________________
# merge_344 (Merge)               (None, 35, 35, 128)  0           conv2d_988[0][0]
#                                                                  conv2d_990[0][0]
#                                                                  conv2d_993[0][0]
# __________________________________________________________________________________________________
# conv2d_994 (Conv2D)             (None, 35, 35, 384)  49536       merge_344[0][0]
# __________________________________________________________________________________________________
# lambda_161 (Lambda)             (None, 35, 35, 384)  0           conv2d_994[0][0]
# __________________________________________________________________________________________________
# merge_345 (Merge)               (None, 35, 35, 384)  0           activation_173[0][0]
#                                                                  lambda_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 35, 35, 384)  1536        merge_345[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 35, 35, 384)  0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# conv2d_998 (Conv2D)             (None, 35, 35, 32)   12320       activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_996 (Conv2D)             (None, 35, 35, 32)   12320       activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_999 (Conv2D)             (None, 35, 35, 48)   13872       conv2d_998[0][0]
# __________________________________________________________________________________________________
# conv2d_995 (Conv2D)             (None, 35, 35, 32)   12320       activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_997 (Conv2D)             (None, 35, 35, 32)   9248        conv2d_996[0][0]
# __________________________________________________________________________________________________
# conv2d_1000 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_999[0][0]
# __________________________________________________________________________________________________
# merge_346 (Merge)               (None, 35, 35, 128)  0           conv2d_995[0][0]
#                                                                  conv2d_997[0][0]
#                                                                  conv2d_1000[0][0]
# __________________________________________________________________________________________________
# conv2d_1001 (Conv2D)            (None, 35, 35, 384)  49536       merge_346[0][0]
# __________________________________________________________________________________________________
# lambda_162 (Lambda)             (None, 35, 35, 384)  0           conv2d_1001[0][0]
# __________________________________________________________________________________________________
# merge_347 (Merge)               (None, 35, 35, 384)  0           activation_174[0][0]
#                                                                  lambda_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 35, 35, 384)  1536        merge_347[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 35, 35, 384)  0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# conv2d_1005 (Conv2D)            (None, 35, 35, 32)   12320       activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d_1003 (Conv2D)            (None, 35, 35, 32)   12320       activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d_1006 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1005[0][0]
# __________________________________________________________________________________________________
# conv2d_1002 (Conv2D)            (None, 35, 35, 32)   12320       activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d_1004 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1003[0][0]
# __________________________________________________________________________________________________
# conv2d_1007 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1006[0][0]
# __________________________________________________________________________________________________
# merge_348 (Merge)               (None, 35, 35, 128)  0           conv2d_1002[0][0]
#                                                                  conv2d_1004[0][0]
#                                                                  conv2d_1007[0][0]
# __________________________________________________________________________________________________
# conv2d_1008 (Conv2D)            (None, 35, 35, 384)  49536       merge_348[0][0]
# __________________________________________________________________________________________________
# lambda_163 (Lambda)             (None, 35, 35, 384)  0           conv2d_1008[0][0]
# __________________________________________________________________________________________________
# merge_349 (Merge)               (None, 35, 35, 384)  0           activation_175[0][0]
#                                                                  lambda_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 35, 35, 384)  1536        merge_349[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 35, 35, 384)  0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_1012 (Conv2D)            (None, 35, 35, 32)   12320       activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_1010 (Conv2D)            (None, 35, 35, 32)   12320       activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_1013 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1012[0][0]
# __________________________________________________________________________________________________
# conv2d_1009 (Conv2D)            (None, 35, 35, 32)   12320       activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_1011 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1010[0][0]
# __________________________________________________________________________________________________
# conv2d_1014 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1013[0][0]
# __________________________________________________________________________________________________
# merge_350 (Merge)               (None, 35, 35, 128)  0           conv2d_1009[0][0]
#                                                                  conv2d_1011[0][0]
#                                                                  conv2d_1014[0][0]
# __________________________________________________________________________________________________
# conv2d_1015 (Conv2D)            (None, 35, 35, 384)  49536       merge_350[0][0]
# __________________________________________________________________________________________________
# lambda_164 (Lambda)             (None, 35, 35, 384)  0           conv2d_1015[0][0]
# __________________________________________________________________________________________________
# merge_351 (Merge)               (None, 35, 35, 384)  0           activation_176[0][0]
#                                                                  lambda_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 35, 35, 384)  1536        merge_351[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 35, 35, 384)  0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_1019 (Conv2D)            (None, 35, 35, 32)   12320       activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d_1017 (Conv2D)            (None, 35, 35, 32)   12320       activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d_1020 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1019[0][0]
# __________________________________________________________________________________________________
# conv2d_1016 (Conv2D)            (None, 35, 35, 32)   12320       activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d_1018 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1017[0][0]
# __________________________________________________________________________________________________
# conv2d_1021 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1020[0][0]
# __________________________________________________________________________________________________
# merge_352 (Merge)               (None, 35, 35, 128)  0           conv2d_1016[0][0]
#                                                                  conv2d_1018[0][0]
#                                                                  conv2d_1021[0][0]
# __________________________________________________________________________________________________
# conv2d_1022 (Conv2D)            (None, 35, 35, 384)  49536       merge_352[0][0]
# __________________________________________________________________________________________________
# lambda_165 (Lambda)             (None, 35, 35, 384)  0           conv2d_1022[0][0]
# __________________________________________________________________________________________________
# merge_353 (Merge)               (None, 35, 35, 384)  0           activation_177[0][0]
#                                                                  lambda_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 35, 35, 384)  1536        merge_353[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 35, 35, 384)  0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv2d_1026 (Conv2D)            (None, 35, 35, 32)   12320       activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_1024 (Conv2D)            (None, 35, 35, 32)   12320       activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_1027 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1026[0][0]
# __________________________________________________________________________________________________
# conv2d_1023 (Conv2D)            (None, 35, 35, 32)   12320       activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_1025 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1024[0][0]
# __________________________________________________________________________________________________
# conv2d_1028 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1027[0][0]
# __________________________________________________________________________________________________
# merge_354 (Merge)               (None, 35, 35, 128)  0           conv2d_1023[0][0]
#                                                                  conv2d_1025[0][0]
#                                                                  conv2d_1028[0][0]
# __________________________________________________________________________________________________
# conv2d_1029 (Conv2D)            (None, 35, 35, 384)  49536       merge_354[0][0]
# __________________________________________________________________________________________________
# lambda_166 (Lambda)             (None, 35, 35, 384)  0           conv2d_1029[0][0]
# __________________________________________________________________________________________________
# merge_355 (Merge)               (None, 35, 35, 384)  0           activation_178[0][0]
#                                                                  lambda_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 35, 35, 384)  1536        merge_355[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 35, 35, 384)  0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# conv2d_1033 (Conv2D)            (None, 35, 35, 32)   12320       activation_179[0][0]
# __________________________________________________________________________________________________
# conv2d_1031 (Conv2D)            (None, 35, 35, 32)   12320       activation_179[0][0]
# __________________________________________________________________________________________________
# conv2d_1034 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1033[0][0]
# __________________________________________________________________________________________________
# conv2d_1030 (Conv2D)            (None, 35, 35, 32)   12320       activation_179[0][0]
# __________________________________________________________________________________________________
# conv2d_1032 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1031[0][0]
# __________________________________________________________________________________________________
# conv2d_1035 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1034[0][0]
# __________________________________________________________________________________________________
# merge_356 (Merge)               (None, 35, 35, 128)  0           conv2d_1030[0][0]
#                                                                  conv2d_1032[0][0]
#                                                                  conv2d_1035[0][0]
# __________________________________________________________________________________________________
# conv2d_1036 (Conv2D)            (None, 35, 35, 384)  49536       merge_356[0][0]
# __________________________________________________________________________________________________
# lambda_167 (Lambda)             (None, 35, 35, 384)  0           conv2d_1036[0][0]
# __________________________________________________________________________________________________
# merge_357 (Merge)               (None, 35, 35, 384)  0           activation_179[0][0]
#                                                                  lambda_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 35, 35, 384)  1536        merge_357[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 35, 35, 384)  0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# conv2d_1040 (Conv2D)            (None, 35, 35, 32)   12320       activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_1038 (Conv2D)            (None, 35, 35, 32)   12320       activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_1041 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1040[0][0]
# __________________________________________________________________________________________________
# conv2d_1037 (Conv2D)            (None, 35, 35, 32)   12320       activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_1039 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1038[0][0]
# __________________________________________________________________________________________________
# conv2d_1042 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1041[0][0]
# __________________________________________________________________________________________________
# merge_358 (Merge)               (None, 35, 35, 128)  0           conv2d_1037[0][0]
#                                                                  conv2d_1039[0][0]
#                                                                  conv2d_1042[0][0]
# __________________________________________________________________________________________________
# conv2d_1043 (Conv2D)            (None, 35, 35, 384)  49536       merge_358[0][0]
# __________________________________________________________________________________________________
# lambda_168 (Lambda)             (None, 35, 35, 384)  0           conv2d_1043[0][0]
# __________________________________________________________________________________________________
# merge_359 (Merge)               (None, 35, 35, 384)  0           activation_180[0][0]
#                                                                  lambda_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 35, 35, 384)  1536        merge_359[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 35, 35, 384)  0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_1047 (Conv2D)            (None, 35, 35, 32)   12320       activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_1045 (Conv2D)            (None, 35, 35, 32)   12320       activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_1048 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1047[0][0]
# __________________________________________________________________________________________________
# conv2d_1044 (Conv2D)            (None, 35, 35, 32)   12320       activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_1046 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1045[0][0]
# __________________________________________________________________________________________________
# conv2d_1049 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1048[0][0]
# __________________________________________________________________________________________________
# merge_360 (Merge)               (None, 35, 35, 128)  0           conv2d_1044[0][0]
#                                                                  conv2d_1046[0][0]
#                                                                  conv2d_1049[0][0]
# __________________________________________________________________________________________________
# conv2d_1050 (Conv2D)            (None, 35, 35, 384)  49536       merge_360[0][0]
# __________________________________________________________________________________________________
# lambda_169 (Lambda)             (None, 35, 35, 384)  0           conv2d_1050[0][0]
# __________________________________________________________________________________________________
# merge_361 (Merge)               (None, 35, 35, 384)  0           activation_181[0][0]
#                                                                  lambda_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 35, 35, 384)  1536        merge_361[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 35, 35, 384)  0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv2d_1054 (Conv2D)            (None, 35, 35, 32)   12320       activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d_1052 (Conv2D)            (None, 35, 35, 32)   12320       activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d_1055 (Conv2D)            (None, 35, 35, 48)   13872       conv2d_1054[0][0]
# __________________________________________________________________________________________________
# conv2d_1051 (Conv2D)            (None, 35, 35, 32)   12320       activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d_1053 (Conv2D)            (None, 35, 35, 32)   9248        conv2d_1052[0][0]
# __________________________________________________________________________________________________
# conv2d_1056 (Conv2D)            (None, 35, 35, 64)   27712       conv2d_1055[0][0]
# __________________________________________________________________________________________________
# merge_362 (Merge)               (None, 35, 35, 128)  0           conv2d_1051[0][0]
#                                                                  conv2d_1053[0][0]
#                                                                  conv2d_1056[0][0]
# __________________________________________________________________________________________________
# conv2d_1057 (Conv2D)            (None, 35, 35, 384)  49536       merge_362[0][0]
# __________________________________________________________________________________________________
# lambda_170 (Lambda)             (None, 35, 35, 384)  0           conv2d_1057[0][0]
# __________________________________________________________________________________________________
# merge_363 (Merge)               (None, 35, 35, 384)  0           activation_182[0][0]
#                                                                  lambda_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 35, 35, 384)  1536        merge_363[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 35, 35, 384)  0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_1059 (Conv2D)            (None, 35, 35, 256)  98560       activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d_1060 (Conv2D)            (None, 35, 35, 256)  590080      conv2d_1059[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 17, 17, 384)  0           activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d_1058 (Conv2D)            (None, 17, 17, 384)  1327488     activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d_1061 (Conv2D)            (None, 17, 17, 384)  885120      conv2d_1060[0][0]
# __________________________________________________________________________________________________
# merge_364 (Merge)               (None, 17, 17, 1152) 0           max_pooling2d_19[0][0]
#                                                                  conv2d_1058[0][0]
#                                                                  conv2d_1061[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 17, 17, 1152) 68          merge_364[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_1063 (Conv2D)            (None, 17, 17, 128)  147584      activation_184[0][0]
# __________________________________________________________________________________________________
# conv2d_1064 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1063[0][0]
# __________________________________________________________________________________________________
# conv2d_1062 (Conv2D)            (None, 17, 17, 192)  221376      activation_184[0][0]
# __________________________________________________________________________________________________
# conv2d_1065 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1064[0][0]
# __________________________________________________________________________________________________
# merge_365 (Merge)               (None, 17, 17, 384)  0           conv2d_1062[0][0]
#                                                                  conv2d_1065[0][0]
# __________________________________________________________________________________________________
# conv2d_1066 (Conv2D)            (None, 17, 17, 1152) 443520      merge_365[0][0]
# __________________________________________________________________________________________________
# lambda_171 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1066[0][0]
# __________________________________________________________________________________________________
# merge_366 (Merge)               (None, 17, 17, 1152) 0           activation_184[0][0]
#                                                                  lambda_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 17, 17, 1152) 4608        merge_366[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv2d_1068 (Conv2D)            (None, 17, 17, 128)  147584      activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d_1069 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1067 (Conv2D)            (None, 17, 17, 192)  221376      activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d_1070 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1069[0][0]
# __________________________________________________________________________________________________
# merge_367 (Merge)               (None, 17, 17, 384)  0           conv2d_1067[0][0]
#                                                                  conv2d_1070[0][0]
# __________________________________________________________________________________________________
# conv2d_1071 (Conv2D)            (None, 17, 17, 1152) 443520      merge_367[0][0]
# __________________________________________________________________________________________________
# lambda_172 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1071[0][0]
# __________________________________________________________________________________________________
# merge_368 (Merge)               (None, 17, 17, 1152) 0           activation_185[0][0]
#                                                                  lambda_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 17, 17, 1152) 4608        merge_368[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_1073 (Conv2D)            (None, 17, 17, 128)  147584      activation_186[0][0]
# __________________________________________________________________________________________________
# conv2d_1074 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1072 (Conv2D)            (None, 17, 17, 192)  221376      activation_186[0][0]
# __________________________________________________________________________________________________
# conv2d_1075 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1074[0][0]
# __________________________________________________________________________________________________
# merge_369 (Merge)               (None, 17, 17, 384)  0           conv2d_1072[0][0]
#                                                                  conv2d_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1076 (Conv2D)            (None, 17, 17, 1152) 443520      merge_369[0][0]
# __________________________________________________________________________________________________
# lambda_173 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1076[0][0]
# __________________________________________________________________________________________________
# merge_370 (Merge)               (None, 17, 17, 1152) 0           activation_186[0][0]
#                                                                  lambda_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 17, 17, 1152) 4608        merge_370[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_1078 (Conv2D)            (None, 17, 17, 128)  147584      activation_187[0][0]
# __________________________________________________________________________________________________
# conv2d_1079 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1078[0][0]
# __________________________________________________________________________________________________
# conv2d_1077 (Conv2D)            (None, 17, 17, 192)  221376      activation_187[0][0]
# __________________________________________________________________________________________________
# conv2d_1080 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1079[0][0]
# __________________________________________________________________________________________________
# merge_371 (Merge)               (None, 17, 17, 384)  0           conv2d_1077[0][0]
#                                                                  conv2d_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1081 (Conv2D)            (None, 17, 17, 1152) 443520      merge_371[0][0]
# __________________________________________________________________________________________________
# lambda_174 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1081[0][0]
# __________________________________________________________________________________________________
# merge_372 (Merge)               (None, 17, 17, 1152) 0           activation_187[0][0]
#                                                                  lambda_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 17, 17, 1152) 4608        merge_372[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_1083 (Conv2D)            (None, 17, 17, 128)  147584      activation_188[0][0]
# __________________________________________________________________________________________________
# conv2d_1084 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1082 (Conv2D)            (None, 17, 17, 192)  221376      activation_188[0][0]
# __________________________________________________________________________________________________
# conv2d_1085 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1084[0][0]
# __________________________________________________________________________________________________
# merge_373 (Merge)               (None, 17, 17, 384)  0           conv2d_1082[0][0]
#                                                                  conv2d_1085[0][0]
# __________________________________________________________________________________________________
# conv2d_1086 (Conv2D)            (None, 17, 17, 1152) 443520      merge_373[0][0]
# __________________________________________________________________________________________________
# lambda_175 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1086[0][0]
# __________________________________________________________________________________________________
# merge_374 (Merge)               (None, 17, 17, 1152) 0           activation_188[0][0]
#                                                                  lambda_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 17, 17, 1152) 4608        merge_374[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_1088 (Conv2D)            (None, 17, 17, 128)  147584      activation_189[0][0]
# __________________________________________________________________________________________________
# conv2d_1089 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1088[0][0]
# __________________________________________________________________________________________________
# conv2d_1087 (Conv2D)            (None, 17, 17, 192)  221376      activation_189[0][0]
# __________________________________________________________________________________________________
# conv2d_1090 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1089[0][0]
# __________________________________________________________________________________________________
# merge_375 (Merge)               (None, 17, 17, 384)  0           conv2d_1087[0][0]
#                                                                  conv2d_1090[0][0]
# __________________________________________________________________________________________________
# conv2d_1091 (Conv2D)            (None, 17, 17, 1152) 443520      merge_375[0][0]
# __________________________________________________________________________________________________
# lambda_176 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1091[0][0]
# __________________________________________________________________________________________________
# merge_376 (Merge)               (None, 17, 17, 1152) 0           activation_189[0][0]
#                                                                  lambda_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 17, 17, 1152) 4608        merge_376[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 17, 17, 1152) 0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_1093 (Conv2D)            (None, 17, 17, 128)  147584      activation_190[0][0]
# __________________________________________________________________________________________________
# conv2d_1094 (Conv2D)            (None, 17, 17, 160)  143520      conv2d_1093[0][0]
# __________________________________________________________________________________________________
# conv2d_1092 (Conv2D)            (None, 17, 17, 192)  221376      activation_190[0][0]
# __________________________________________________________________________________________________
# conv2d_1095 (Conv2D)            (None, 17, 17, 192)  215232      conv2d_1094[0][0]
# __________________________________________________________________________________________________
# merge_377 (Merge)               (None, 17, 17, 384)  0           conv2d_1092[0][0]
#                                                                  conv2d_1095[0][0]
# __________________________________________________________________________________________________
# conv2d_1096 (Conv2D)            (None, 17, 17, 1152) 443520      merge_377[0][0]
# __________________________________________________________________________________________________
# lambda_177 (Lambda)             (None, 17, 17, 1152) 0           conv2d_1096[0][0]
# __________________________________________________________________________________________________
# merge_378 (Merge)               (None, 17, 17, 1152) 0           activation_190[0][0]
#                                                                  lambda_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 17, 17, 1152) 4608        merge_378[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  lambda_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 8, 8, 2144)   8576        merge_413[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_1192 (Conv2D)            (None, 8, 8, 192)    411840      activation_209[0][0]
# __________________________________________________________________________________________________
# conv2d_1193 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1192[0][0]
# __________________________________________________________________________________________________
# conv2d_1191 (Conv2D)            (None, 8, 8, 192)    411840      activation_209[0][0]
# __________________________________________________________________________________________________
# conv2d_1194 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1193[0][0]
# __________________________________________________________________________________________________
# merge_414 (Merge)               (None, 8, 8, 448)    0           conv2d_1191[0][0]
#                                                                  conv2d_1194[0][0]
# __________________________________________________________________________________________________
# conv2d_1195 (Conv2D)            (None, 8, 8, 2144)   962656      merge_414[0][0]
# __________________________________________________________________________________________________
# lambda_195 (Lambda)             (None, 8, 8, 2144)   0           conv2d_1195[0][0]
# __________________________________________________________________________________________________
# merge_415 (Merge)               (None, 8, 8, 2144)   0           activation_209[0][0]
#                                                                  lambda_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 8, 8, 2144)   8576        merge_415[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_1197 (Conv2D)            (None, 8, 8, 192)    411840      activation_210[0][0]
# __________________________________________________________________________________________________
# conv2d_1198 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1197[0][0]
# __________________________________________________________________________________________________
# conv2d_1196 (Conv2D)            (None, 8, 8, 192)    411840      activation_210[0][0]
# __________________________________________________________________________________________________
# conv2d_1199 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1198[0][0]
# __________________________________________________________________________________________________
# merge_416 (Merge)               (None, 8, 8, 448)    0           conv2d_1196[0][0]
#                                                                  conv2d_1199[0][0]
# __________________________________________________________________________________________________
# conv2d_1200 (Conv2D)            (None, 8, 8, 2144)   962656      merge_416[0][0]
# __________________________________________________________________________________________________
# lambda_196 (Lambda)             (None, 8, 8, 2144)   0           conv2d_1200[0][0]
# __________________________________________________________________________________________________
# merge_417 (Merge)               (None, 8, 8, 2144)   0           activation_210[0][0]
#                                                                  lambda_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 8, 8, 2144)   8576        merge_417[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_1202 (Conv2D)            (None, 8, 8, 192)    411840      activation_211[0][0]
# __________________________________________________________________________________________________
# conv2d_1203 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1202[0][0]
# __________________________________________________________________________________________________
# conv2d_1201 (Conv2D)            (None, 8, 8, 192)    411840      activation_211[0][0]
# __________________________________________________________________________________________________
# conv2d_1204 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1203[0][0]
# __________________________________________________________________________________________________
# merge_418 (Merge)               (None, 8, 8, 448)    0           conv2d_1201[0][0]
#                                                                  conv2d_1204[0][0]
# __________________________________________________________________________________________________
# conv2d_1205 (Conv2D)            (None, 8, 8, 2144)   962656      merge_418[0][0]
# __________________________________________________________________________________________________
# lambda_197 (Lambda)             (None, 8, 8, 2144)   0           conv2d_1205[0][0]
# __________________________________________________________________________________________________
# merge_419 (Merge)               (None, 8, 8, 2144)   0           activation_211[0][0]
#                                                                  lambda_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 8, 8, 2144)   8576        merge_419[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_1207 (Conv2D)            (None, 8, 8, 192)    411840      activation_212[0][0]
# __________________________________________________________________________________________________
# conv2d_1208 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1207[0][0]
# __________________________________________________________________________________________________
# conv2d_1206 (Conv2D)            (None, 8, 8, 192)    411840      activation_212[0][0]
# __________________________________________________________________________________________________
# conv2d_1209 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1208[0][0]
# __________________________________________________________________________________________________
# merge_420 (Merge)               (None, 8, 8, 448)    0           conv2d_1206[0][0]
#                                                                  conv2d_1209[0][0]
# __________________________________________________________________________________________________
# conv2d_1210 (Conv2D)            (None, 8, 8, 2144)   962656      merge_420[0][0]
# __________________________________________________________________________________________________
# lambda_198 (Lambda)             (None, 8, 8, 2144)   0           conv2d_1210[0][0]
# __________________________________________________________________________________________________
# merge_421 (Merge)               (None, 8, 8, 2144)   0           activation_212[0][0]
#                                                                  lambda_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 8, 8, 2144)   8576        merge_421[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_1212 (Conv2D)            (None, 8, 8, 192)    411840      activation_213[0][0]
# __________________________________________________________________________________________________
# conv2d_1213 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1212[0][0]
# __________________________________________________________________________________________________
# conv2d_1211 (Conv2D)            (None, 8, 8, 192)    411840      activation_213[0][0]
# __________________________________________________________________________________________________
# conv2d_1214 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1213[0][0]
# __________________________________________________________________________________________________
# merge_422 (Merge)               (None, 8, 8, 448)    0           conv2d_1211[0][0]
#                                                                  conv2d_1214[0][0]
# __________________________________________________________________________________________________
# conv2d_1215 (Conv2D)            (None, 8, 8, 2144)   962656      merge_422[0][0]
# __________________________________________________________________________________________________
# lambda_199 (Lambda)             (None, 8, 8, 2144)   0           conv2d_1215[0][0]
# __________________________________________________________________________________________________
# merge_423 (Merge)               (None, 8, 8, 2144)   0           activation_213[0][0]
#                                                                  lambda_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 8, 8, 2144)   8576        merge_423[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_1217 (Conv2D)            (None, 8, 8, 192)    411840      activation_214[0][0]
# __________________________________________________________________________________________________
# conv2d_1218 (Conv2D)            (None, 8, 8, 224)    129248      conv2d_1217[0][0]
# __________________________________________________________________________________________________
# conv2d_1216 (Conv2D)            (None, 8, 8, 192)    411840      activation_214[0][0]
# __________________________________________________________________________________________________
# conv2d_1219 (Conv2D)            (None, 8, 8, 256)    172288      conv2d_1218[0][0]
# __________________________________________________________________________________________________
# merge_424 (Merge)               (None, 8, 8, 448)    0           conv2d_1216[0][0]
#                                                                  conv2d_1219[0][0]
# __________________________________________________________________________________________________
# conv2d_1220 (Conv2D)            (None, 8, 8, 2144)   962656      merge_424[0][0]
# __________________________________________________________________________________________________
# lambda_200 (Lambda)             (None, 8, 8, 2144)   0           conv2d_1220[0][0]
# __________________________________________________________________________________________________
# merge_425 (Merge)               (None, 8, 8, 2144)   0           activation_214[0][0]
#                                                                  lambda_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 8, 8, 2144)   8576        merge_425[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 8, 8, 2144)   0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 1152)   0           activation_204[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 1, 1, 2144)   0           activation_215[0][0]
# __________________________________________________________________________________________________
# conv2d_1162 (Conv2D)            (None, 5, 5, 128)    147584      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1, 1, 2144)   0           average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_1163 (Conv2D)            (None, 1, 1, 768)    2458368     conv2d_1162[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 2144)         0           dropout_5[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 768)          0           conv2d_1163[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1001)         2147145     flatten_10[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1001)         769769      flatten_9[0][0]
# ==================================================================================================
# Total params: 58,837,142
# Trainable params: 58,735,412
# Non-trainable params: 101,730
# __________________________________________________________________________________________________
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f7520b53e0c1> in <module>()
#     256
#     257     i = 0
# --> 258     for layer in model.layers[:]:
#     259         i = i +1
#     260     print(i)
#
# NameError: name 'model' is not defined

# %%
    i = 0
    for layer in res2.layers[:]:
        i = i +1
    print(i)
    
    print(res2.layers[-3])
# Out:
# 467
# <keras.layers.core.Flatten object at 0x144cb5f98>
